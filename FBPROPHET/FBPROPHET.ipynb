# %% [markdown]
# # making predications using fbprophet

# %% [markdown]
# #

# %%
import pandas as pd
import matplotlib as mplt

# %%
from fbprophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
df = pd.read_csv('data2.csv')

# %%
df.shape
# Out:
# (863, 2)

# %%
df.columns
# Out:
# Index(['ds', 'y'], dtype='object')

# %%
df.head()
# Out:
#                     ds    y
# 0  2017-01-01 00:05:00  0.0
# 1  2017-01-01 00:10:00  0.0
# 2  2017-01-01 00:15:00  0.0
# 3  2017-01-01 00:20:00  0.0
# 4  2017-01-01 00:25:00 -0.1

# %%
df.dtypes
# Out:
# ds     object
# y     float64
# dtype: object

# %%
m = Prophet()

# %%
m.add_seasonality(name="Yearly",period=365,fourier_order=5)

# %%
m.add_seasonality(name="Weekly",period=7,fourier_order=5)

# %%
m.fit(df)
forecast = m.predict(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head()
# Out:
#                    ds      yhat  yhat_lower  yhat_upper
# 0 2017-01-01 00:05:00 -0.119286   -1.156238    0.873493
# 1 2017-01-01 00:10:00 -0.102842   -1.130157    0.889443
# 2 2017-01-01 00:15:00 -0.088752   -1.029765    0.989374
# 3 2017-01-01 00:20:00 -0.076845   -1.042250    0.927307
# 4 2017-01-01 00:25:00 -0.066956   -1.028528    0.937564

# %%
fig1 = m.plot(forecast)

# %%
figure = m.plot_components(forecast)
